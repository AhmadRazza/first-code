# %%
# !nvcc --version
# https://pytorch.org/get-started/locally/
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124

# %%
# !pip install git+https://github.com/SWivid/F5-TTS.git
from IPython.display import clear_output
clear_output()

# %%
# !f5-tts_infer-gradio --share
# Out:
# 2025-12-24 05:32:58.615231: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766554378.650185    1413 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766554378.658451    1413 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766554378.682441    1413 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766554378.682472    1413 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766554378.682480    1413 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766554378.682486    1413 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-24 05:32:58.689031: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Download Vocos from huggingface charactr/vocos-mel-24khz
# config.yaml: 100% 461/461 [00:00<00:00, 3.99MB/s]
# pytorch_model.bin: 100% 54.4M/54.4M [00:01<00:00, 36.9MB/s]
# F5TTS_v1_Base/model_1250000.safetensors: 100% 1.35G/1.35G [00:09<00:00, 145MB/s]
#
# vocab :  /usr/local/lib/python3.12/dist-packages/f5_tts/infer/examples/vocab.txt
# token :  custom
# model :  /root/.cache/huggingface/hub/models--SWivid--F5-TTS/snapshots/84e5a410d9cead4de2f847e7c9369a6440bdfaca/F5TTS_v1_Base/model_1250000.safetensors
#
# Starting app...
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://84300d21bccb5b4206.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# config.json: 1.26kB [00:00, 5.83MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors: 100% 1.62G/1.62G [00:11<00:00, 138MB/s]
# generation_config.json: 3.77kB [00:00, 8.41MB/s]
# tokenizer_config.json: 283kB [00:00, 232MB/s]
# vocab.json: 1.04MB [00:00, 38.8MB/s]
# tokenizer.json: 2.71MB [00:00, 156MB/s]
# merges.txt: 494kB [00:00, 109MB/s]
# normalizer.json: 52.7kB [00:00, 74.2MB/s]
# added_tokens.json: 34.6kB [00:00, 63.5MB/s]
# special_tokens_map.json: 2.19kB [00:00, 19.5MB/s]
# preprocessor_config.json: 100% 340/340 [00:00<00:00, 3.26MB/s]
# Device set to use cuda
# Using `chunk_length_s` is very experimental with seq2seq models. The results will not necessarily be entirely accurate and will have caveats. More information: https://github.com/huggingface/transformers/pull/20104. Ignore this warning with pipeline(..., ignore_warning=True). To use Whisper for long-form transcription, use rather the model's `generate` method directly as the model relies on it's own chunking mechanism (cf. Whisper original paper, section 3.8. Long-form Transcription).
#
# ref_text   back asleep. Vitamin C helps regulate this system by supporting adrenal resilience and lowering excess cortisol levels. Studies show that individuals with higher vitamin C.
# gen_text 0 "Imagine being able to reprogram your mind so fast, it feels almost unbelievable… what if the life you’ve always dreamed of could start changing today,
# gen_text 1 simply by aligning your thoughts and emotions? Stay with me, because what you’re about to hear could transform the way you think, feel, and live—and yes, it works shockingly fast!
# gen_text 2 Don’t forget to hit subscribe, like, and turn on notifications so you never miss a chance to unlock your true potential."
# Close your eyes for a moment—and consider this truth:
# gen_text 3 You are not here to fix yourself. You are here to remember who you really are. Every thought you think sends a signal into your brain. Every emotion you feel sends a message to your body.
# gen_text 4 And when those two begin to work together—not against each other—something extraordinary happens. Change doesn’t take years. It doesn’t take struggle. It doesn’t take suffering.
# gen_text 5 It takes clarity. The moment you stop rehearsing the past, The moment you stop predicting the same future,
# gen_text 6 The moment you interrupt the emotional addiction to who you’ve been—
#
# You create space. And in that space…
# The nervous system listens. The subconscious opens.
# gen_text 7 And the body begins to reorganize itself around a new signal. Most people wait for their life to change before they feel different. But that’s backward.
# gen_text 8 You don’t think greater after you heal—
# You heal because you think greater. When you combine a clear intention with an elevated emotion, You are no longer living in survival.
# gen_text 9 You are teaching your body what the future feels like—now. And the body does not know the difference between an experience happening in the outer world
# and one created vividly in the mind.
# gen_text 10 So when you feel gratitude before the event occurs, When you feel freedom before the chains are gone, When you feel wholeness before the evidence appears—
#
# Your biology begins to shift.
# gen_text 11 This is not hope. This is not belief. This is training. Every time you return to the present moment, You pull energy out of the past. Every time you choose a new emotion,
# gen_text 12 You rewrite the chemical signature of your identity. And suddenly—
# Your reactions change. Your habits dissolve. Your body responds. That’s when it happens fast.
# gen_text 13 Not because time collapsed—
# But because resistance disappeared. So today, decide this: No more living as the memory of yesterday. No more rehearsing the same emotional scripts.
# gen_text 14 No more waiting for permission to change. Become the signal now. Think, feel, act, and live as if the transformation has already occurred.
# gen_text 15 Because when the mind and body are aligned—
# Reality has no choice but to follow. And that’s when you realize…
#
# It was never outside of you. It was always waiting within you.
# gen_text 16 The mind is not a static structure locked into predetermined patterns; it is a living, adaptive system that is constantly shaped by experience, focus, and repetition.
# gen_text 17 Every thought you think activates specific neural networks, and the more frequently those networks are activated, the stronger and more automatic they become. In this way,
# gen_text 18 the mind functions much like software—running programs that were installed through past experiences, emotional reactions, conditioning, and belief systems.
# gen_text 19 Many of these programs operate beneath conscious awareness, silently influencing behavior, perception, and decision-making. What feels like personality, habit,
# gen_text 20 or fate is often nothing more than a well-rehearsed neurological pattern. The powerful truth is that these patterns are not permanent. The brain is designed to learn, unlearn,
# gen_text 21 and reorganize itself throughout life. When attention is deliberately placed on new thoughts and paired with intentional emotional states, new neural connections begin to form. Over time,
# gen_text 22 these connections can replace outdated programs that no longer serve growth or well-being. By becoming aware of habitual thinking and consciously choosing new mental inputs,
# gen_text 23 the mind can be rewritten. This process does not require force, but presence, repetition, and emotional engagement. When the mind receives consistent new signals,
# gen_text 24 it adapts—because adaptation is its natural function. Change is often believed to be slow because the mind has been conditioned to associate transformation with effort, time, and struggle.
# gen_text 25 In reality, the true limitation is not how fast the brain or body can change, but what a person believes is possible for them. The moment the mind accepts a new internal truth,
# gen_text 26 the nervous system begins responding immediately. Belief acts as a filter for perception; it determines what signals the brain allows in and which ones it rejects.
# gen_text 27 When someone secretly doubts their ability to change, the subconscious maintains the familiar patterns, even if those patterns create discomfort.
# gen_text 28 The body then remains chemically addicted to the past, reinforcing the illusion that change must be difficult. However, when belief shifts, resistance dissolves.
# gen_text 29 The brain stops defending the old identity and becomes receptive to new instructions. This is why breakthroughs can feel sudden and dramatic—not because something magical occurred,
# gen_text 30 but because the internal barrier was removed. The body is always ready to follow the mind once it receives a clear, confident signal. When belief aligns with intention,
# gen_text 31 the subconscious no longer asks for proof; it accepts direction. In that state, change can unfold with surprising speed, because nothing within is working against it.
# gen_text 32 Every thought that arises in the mind is an electrical event, a measurable signal moving through neural circuits in the brain. When a thought is repeated,
# gen_text 33 those electrical signals travel the same pathways again and again, strengthening the connections like wires being reinforced through use. At the same time,
# gen_text 34 every emotion associated with that thought releases a cascade of chemical messengers throughout the body. These chemicals influence mood, immune response, hormones, and even gene expression.
# gen_text 35 In this way, thoughts and emotions work together as a complete communication system, linking the brain to every cell.
# gen_text 36 When a person thinks fear-based or limiting thoughts and repeatedly feels the emotions of stress, guilt, or anger, the body becomes conditioned to live in those chemical states. Over time,
# gen_text 37 the body begins to crave them, creating an unconscious cycle where the same thoughts are generated simply to maintain familiar feelings. Conversely,
# gen_text 38 when elevated thoughts are paired with empowering emotions such as gratitude, confidence, or inspiration, the body receives a new chemical signature. This combination signals safety, possibility,
# gen_text 39 and growth. The subconscious responds not to logic, but to repetition and feeling. When thoughts and emotions are intentionally aligned, they send a coherent message to the body,
# gen_text 40 instructing it to reorganize itself around a new internal state. The subconscious mind is constantly absorbing information, yet it does not reason or analyze in the way the conscious mind does;
# gen_text 41 it learns primarily through repetition and the emotional intensity attached to experiences. Every idea, belief,
# gen_text 42 or habit that is repeated consistently begins to imprint itself on the subconscious as a form of internal truth. When a thought is paired with a strong emotion,
# gen_text 43 the mind does not distinguish between imagined experiences and lived experiences—it accepts them as reality. This is why visualization, meditation,
# gen_text 44 and intentional emotional practice are so powerful: they allow new programs to be installed in the subconscious without external validation. Habits, behaviors,
# gen_text 45 and responses that once felt automatic can be replaced when the mind is repeatedly exposed to new patterns, reinforced with feeling, and experienced as real internally.
# gen_text 46 The subconscious is like fertile soil, waiting for seeds to be planted; those seeds will grow according to the frequency, intensity, and care with which they are nurtured. Small,
# gen_text 47 consistent acts of intentional thought and feeling gradually replace old, limiting programs with new ones aligned with higher potential. Over time,
# gen_text 48 these new subconscious instructions influence every choice, every reaction, and every perception, ultimately shaping the life that emerges naturally from these rewired internal patterns.
# gen_text 49 Breaking the habit of the old self requires conscious awareness and deliberate effort because so much of human behavior is automated. From the moment we wake,
# gen_text 50 the mind and body operate largely on familiar patterns, often repeating the same thoughts, reactions, and emotional responses that have been reinforced over years, even decades.
# gen_text 51 These patterns are comfortable because they are predictable, but they also limit growth and keep individuals trapped in cycles that no longer serve them. To step into a new version of oneself,
# gen_text 52 it is necessary to interrupt these unconscious routines. This does not mean fighting against the self or forcing change; rather,
# gen_text 53 it means observing habits without judgment and choosing to respond differently. Each moment offers an opportunity to step outside the autopilot and introduce a new thought, a new action,
# gen_text 54 or a new feeling that aligns with the desired future. Over time, these conscious choices retrain neural circuits, replacing outdated behaviors with ones that reflect the new identity.
# gen_text 55 The body and mind gradually adapt, learning to expect new patterns as the norm. Transformation occurs not through external circumstances but by consistently choosing, moment by moment,
# gen_text 56 to live as the person one is becoming, until the old self naturally loses its hold. When the brain and heart are in alignment, the body enters a state of coherence that amplifies clarity,
# gen_text 57 intuition, and the ability to create change. The brain generates electrical activity that organizes thoughts and perception,
# gen_text 58 while the heart produces rhythmic patterns that emit powerful electromagnetic signals throughout the body. When these two systems are synchronized, they communicate in harmony,
# gen_text 59 creating an internal environment where the body responds optimally. Emotions play a central role in this process. Elevated feelings such as gratitude, love,
# gen_text 60 and inspiration create coherent patterns between the heart and brain, which in turn influence the nervous system and chemistry of the body. This coherence enhances mental focus, reduces stress,
# gen_text 61 and allows the subconscious mind to accept new information more readily. It is in this state that true transformation accelerates, because the body no longer resists change but works with it.
# gen_text 62 Habits and old patterns that were previously entrenched begin to dissolve naturally, and new possibilities become accessible. Aligning thought and emotion is not a superficial act;
# gen_text 63 it is a biological signal that communicates to every cell that change is safe and welcome. When this internal coherence is maintained consistently, it opens the door to creativity, healing,
# gen_text 64 and extraordinary performance, allowing a person to live in greater harmony with their highest potential. The present moment is the only point in time where true power exists,
# gen_text 65 yet most people live their lives caught between the past and the future. Memories of what has already happened and worries or plans about what may come occupy attention,
# gen_text 66 pulling energy away from the here and now. When the mind dwells on past experiences, it unconsciously recreates the emotional and neurological states associated with them,
# gen_text 67 keeping the body locked in familiar patterns that limit growth. Similarly, when the mind focuses excessively on the future, it generates anticipation, fear, or desire,
# gen_text 68 which can create tension and reinforce old conditioning. True transformation occurs when attention is fully anchored in the present,
# gen_text 69 when the mind ceases to chase what is no longer real and stops projecting what has not yet arrived. In this state, the nervous system is free to respond to new signals,
# gen_text 70 the subconscious becomes receptive to change, and the body can reorganize around new possibilities. Every thought, feeling,
# gen_text 71 and intention directed in the present moment carries immediate influence, reshaping neural pathways and influencing biological chemistry. By cultivating awareness and presence,
# gen_text 72 a person accesses a state of heightened clarity, creativity, and adaptability. The power of now is not theoretical;
# gen_text 73 it is a tangible force that allows one to consciously design the self and life from a place of full alignment.
# gen_text 74 Rewiring identity before reality changes is a principle that flips the conventional notion of transformation on its head.
# gen_text 75 Most people wait for external circumstances to shift before they feel different or act differently, believing that life must change first to justify inner transformation. In truth,
# gen_text 76 the process begins from the inside out. Identity is the internal blueprint that dictates how we think, feel, and behave,
# gen_text 77 and it is deeply embedded in the subconscious mind through repeated experiences, beliefs, and emotional patterns. To create a new reality,
# gen_text 78 one must first become the person who naturally embodies the changes they desire. This requires consciously adopting thoughts, emotions, and actions aligned with that future self,
# gen_text 79 even before external evidence appears. Each intentional mental and emotional choice signals to the nervous system and subconscious mind that a new identity is emerging. Over time,
# gen_text 80 the body and mind adapt, aligning with this new version of self, and external circumstances begin to reflect the internal transformation. By living as though the desired state is already real,
# gen_text 81 one rewires neural pathways and chemical responses, effectively training the subconscious to support the new identity. This principle emphasizes that true change is an inside job:
# gen_text 82 when identity shifts first, reality cannot help but follow, unfolding naturally in harmony with the self that has already been created.
# gen_text 83 Consistency is the foundation upon which profound transformation is built, because the mind and body are exquisitely sensitive to repetition. Every thought we choose, every emotion we cultivate,
# gen_text 84 and every deliberate action we take sends signals to the nervous system and subconscious mind, slowly reshaping the internal landscape.
# gen_text 85 Change is not about isolated bursts of effort or sudden moments of inspiration; it is the steady, persistent practice of aligning with the desired state day after day.
# gen_text 86 The subconscious mind learns through repetition, and the body responds to the chemical and neurological patterns reinforced consistently over time. Small,
# gen_text 87 intentional acts—when performed regularly—carry far more power than occasional grand gestures, because momentum builds, and new neural pathways strengthen with each reinforcement.
# gen_text 88 Over weeks and months, old habits begin to dissolve, reactions that once felt automatic are replaced with conscious responses, and identity itself begins to shift. The body,
# gen_text 89 which once resisted change, begins to anticipate the new state as familiar and safe. This is why patience is not a limitation but an ally:
# gen_text 90 it allows repetition to take root and produce lasting results. The compounding effect of daily practice transforms internal alignment into visible reality,
# gen_text 91 proving that consistency is the bridge between intention and manifestation. Living as proof of the work means embodying the change internally before expecting it to appear externally.
# gen_text 92 Transformation is not validated by circumstances, possessions, or external approval; it is measured by the alignment between who you are inside and how you show up in the world. When the mind,
# gen_text 93 body, and emotions operate in harmony around a new internal state, the body naturally begins to act in ways that reflect that state. Thoughts, feelings, and behaviors no longer conflict,
# gen_text 94 and the energy emitted through presence and action becomes a living demonstration of internal change. This requires consistent practice, self-awareness, and intentional focus,
# gen_text 95 because the subconscious must be trained to accept and sustain the new patterns. As the internal alignment strengthens, external experiences begin to mirror it—relationships, opportunities,
# gen_text 96 and outcomes shift not because of force or effort, but because the energy driving them has changed. The body, accustomed to old patterns, gradually reorganizes to support the new identity,
# gen_text 97 and the life one experiences becomes an automatic reflection of internal coherence. By living as proof of the work, resistance fades, old habits dissolve, and growth accelerates.
# gen_text 98 This principle teaches that true transformation is not about chasing results, but about being the living embodiment of the reality you wish to create,
# gen_text 99 allowing life itself to respond naturally to the change within. "Now that you’ve seen how powerful your mind can truly be, it’s time to take action. Start rewiring your subconscious,
# gen_text 100 step into your new identity, and watch your life shift in ways you never imagined. If this video inspired you, make sure to like, comment,
# gen_text 101 and share it with your friends—because transformation is even more powerful when it spreads.
# gen_text 102 And don’t forget to subscribe for more tools and techniques to unlock your mind’s full potential. Your future self will thank you!"
